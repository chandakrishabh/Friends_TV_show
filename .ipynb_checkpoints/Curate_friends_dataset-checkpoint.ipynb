# %%
import pandas as pd
import numpy as np
import ssl
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import httplib2
ssl._create_default_https_context = ssl._create_unverified_context
response = urlopen('https://www.python.org')
import matplotlib.pyplot as plt

# %%
#create empty df with 24 episodes per season for 10 seasons
names = ['ross','chandler','joey','monica','phoebe','rachel']
names_5 = ['ross','joey','monica','phoebe','rachel']

seasons = [num if len(num)==2 else '0'+num for num in np.arange(1,11).astype(str) ]
episodes = [num if len(num)==2 else '0'+num for num in np.arange(1,25).astype(str) ]

df = pd.DataFrame(columns = names)
df['Season'],df['Episode'] = '',''
df['Season'] = seasons*len(episodes)
df['Episode'] = np.repeat(episodes,len(seasons))
df['Season'] = pd.to_numeric(df["Season"])
df['Episode'] = pd.to_numeric(df["Episode"])
df.sort_values(by=['Season', 'Episode'],inplace = True)
df.set_index(['Season','Episode'],inplace = True) #not sure if I want to keep this indexing

# %%
seasons = [num if len(num)==2 else '0'+num for num in np.arange(1,11).astype(str) ]
episodes = [num if len(num)==2 else '0'+num for num in np.arange(1,25).astype(str) ]
names_all = []
for season in seasons:
    print(season)
    for episode in episodes:
        url = "https://fangj.github.io/friends/season/"+season+episode+'.html'
        if season =='09' and episode == '23':
            url = 'https://fangj.github.io/friends/season/0923-0924.html'
        if season =='10' and episode =='17':
            url = 'https://fangj.github.io/friends/season/1017-1018.html'
        h = httplib2.Http()
        resp = h.request(url, 'HEAD')
        if int(resp[0]['status']) < 400:
            html = urlopen(url).read()
            soup = BeautifulSoup(html)
            # kill all script and style elements
            for script in soup(["script", "style"]):
                script.extract()    # rip it out
            # get text
            text = soup.get_text()
            # break into lines and remove leading and trailing space on each
            lines = (line.strip() for line in text.splitlines())
            # break multi-headlines into a line each
            chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
            # drop blank lines
            text = '\n'.join(chunk for chunk in chunks if chunk)
#             genqa(text)
            allchars_with_chandler(text,names_all)
# Out:
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10

# %% [markdown]
# # Only for Chandler with other main characters

# %%
def genqa(text):

    f = open("all_lines.txt", "a+",encoding="utf-8")
    q = ''
    a = ''
    p = ''
    aa = False 
    qq = False
    names_5 = ['ross','joey','monica','phoebe','rachel']
    for line in text.split('\n'):

        #if we find a new line with a colon, start either 'q' or 'a' string
        if len(re.findall(r'^.*:',line)) >0:

            #append previous strings if both q and a>0
            if len(a)>0 and len(q)>0:
                a = re.sub("[\(\[].*?[\)\]]", "", a)
                q = re.sub("[\(\[].*?[\)\]]", "", q)
                f.write(' '.join(['Q:',q,'\n']))
                f.write(' '.join(['A:',a,'\n'])) 
                q = ''
                a = ''
                aa= False
                qq = False

            starting = re.findall(r'^.*:',line)[0].split(':')[0].lower()
            if starting in names_5:
                q = ''.join(line.split(':')[1:]).lower()
                qq = True
                aa = False
            if starting == 'chandler' and len(q)>0:
                a=''.join(line.split(':')[1:]).lower()
                aa = True
                qq = False
                
        #else just add to whichever string we have started already
        else:
            if qq == True:
                q=q+' ' +line
            elif aa== True:
                a=a+ ' '+line
                
    #append last set of dialogues            
    if len(a)>0 and len(q)>0:
        a = re.sub("[\(\[].*?[\)\]]", "", a)
        q = re.sub("[\(\[].*?[\)\]]", "", q)
        f.write(' '.join(['Q:',q,'\n']))
        f.write(' '.join(['A:',a,'\n']))             

    f.close()

# %% [markdown]
# # Chandler with all characters

# %%
def allchars_with_chandler(text,names_all):

    f = open("all_characters_lines.txt", "a+",encoding="utf-8")
    q = ''
    a = ''
    p = ''
    aa = False 
    qq = False
    lineskip_count = 0
    for line in text.split('\n'):

        #skip first 7 lines approximately for all the episodes.
        if lineskip_count<7:  
            lineskip_count+=1
            continue


        #if we find a new line with a colon, start either 'q' or 'a' string
        if len(re.findall(r'^.*:',line)) >0:

            #append previous strings if both q and a>0
            if len(a)>0 and len(q)>0:
                a = re.sub("[\(\[].*?[\)\]]", "", a)
                q = re.sub("[\(\[].*?[\)\]]", "", q)
                f.write(' '.join(['Q:',q,'\n']))
                f.write(' '.join(['A:',a,'\n'])) 
                q = ''
                a = ''
                aa= False
                qq = False
                if qname not in names_all:
                    names_all.append(qname)

            starting = ''
            starting = re.findall(r'^.*:',line)[0].split(':')[0].lower()

            if starting == 'chandler' and len(q)>0:
                a=''.join(line.split(':')[1:]).lower()
                aa = True
                qq = False
            elif len(starting)>0:
                q = ''.join(line.split(':')[1:]).lower()
                qname = starting
                qq = True
                aa = False

        #else just add to whichever string we have started already
        else:
            if qq == True:
                q=q+' ' +line
            elif aa== True:
                a=a+ ' '+line

    #append last set of dialogues            
    if len(a)>0 and len(q)>0:
        a = re.sub("[\(\[].*?[\)\]]", "", a)
        q = re.sub("[\(\[].*?[\)\]]", "", q)
        f.write(' '.join(['Q:',q,'\n']))
        f.write(' '.join(['A:',a,'\n']))             

    f.close()

# %%
names_all[-100:]
# Out:
# ['janice\x92s voice',
#  'dana',
#  'elizabeth',
#  'sebastian',
#  'patrick',
#  'audition\x92s not \x91til 5',
#  'paul',
#  'wayne',
#  'the museum official',
#  'male jeweler',
#  'customer',
#  'richard\x92s date',
#  '{transcriber\x92s note',
#  'the photographer',
#  'male student',
#  'celery, and i have one',
#  'tag',
#  'the man',
#  "maitre d'",
#  'male guest',
#  'monica and chandler',
#  'cassie',
#  'waiter in drag',
#  'helena',
#  'the chorus line',
#  'mr. bing',
#  'phoebe and ross',
#  'the rabbi',
#  'bandleader',
#  'dennis phillips',
#  'man at the wedding',
#  'woman at the wedding',
#  'airline employee',
#  'man',
#  'mr. franklin',
#  'bob',
#  'mona',
#  'brenda',
#  'stripper',
#  'hooker',
#  'will',
#  'man on tv',
#  'woman on tv',
#  'don',
#  'parker',
#  '[the next one is from episode 603',
#  '[the next one is from episode 417',
#  '[the next one is from episode 608',
#  'cannot wait to read the front page of the post tomorrow! "restaurant reviewer admits',
#  'the interviewer',
#  'nurse',
#  'ms. mckenna',
#  'ken',
#  'claudia',
#  'ever! the kitchen',
#  'catherine',
#  'they sat us all down yesterday and said "everyone has to be there at 6',
#  'amy',
#  'joey raises his hand',
#  'phoebe while cutting a sweet potatoe in the air',
#  'amy and rachel at same time',
#  'jo lynn',
#  'others',
#  'wendy',
#  'both',
#  'interviewer',
#  'blonde girl',
#  'michelle',
#  'intern',
#  'boss',
#  'handyman',
#  'tom',
#  'kori',
#  'second message',
#  'tv',
#  'steve',
#  '(monica covers her face with her hands)[scene',
#  '(chandler enters the room)ross',
#  '(they make as if to go, but ross notices something)ross',
#  'bitter lady',
#  'opening credits[scene',
#  'doctor connelly',
#  'zack',
#  'closing credits[scene',
#  'david',
#  'charlie',
#  'bill',
#  'owen',
#  'colleen',
#  'amanda',
#  'ross, rachel and chandler',
#  'joey (to chandler)',
#  'laura',
#  'erica',
#  'agency guy',
#  'adoption agency guy',
#  'missy',
#  'jennifer',
#  'monica (enters the room)',
#  'doctor']
